# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,10))
plt.imshow(Image.open('JOINI42h.jpg'))
plt.show()
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'
print(pytesseract.image_to_string(Image.open('JOINI42h.jpg'),lang = "chi_tra"))
# Out:
# ”飲冰室    有集
#
# 小美
#
# 同學會那晚 吃著我最愛的麻辣鍋
# 「你都沒變.還是喜歡吃麻辣,」
# 你露出一抹熟悉的微笑
# 但 你變了
# 變漂亮               讓
# 「偷偷去整形購」我朱
# 「沒有啦 ! 真的沒有,
# 這時我的心悸動著
# 一股暖流經過心窩
# 我又胃食道逆流了
